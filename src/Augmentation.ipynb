# %%
import cv2
import os
import glob
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Tentukan direktori utama
main_directory = '../dataset/preprocessed/Induk anak huruf di samping'

# Konfigurasi augmentasi gambar
datagen = ImageDataGenerator(
    rotation_range=30,    # Rentang rotasi dalam derajat
    shear_range=0.2,      # Rentang pemutarannya
    zoom_range=0.2,       # Rentang zoom-in dan zoom-out
    horizontal_flip=True, # Melakukan flip horizontal
    vertical_flip=True,   # Melakukan flip vertikal
    fill_mode='nearest'   # Cara mengisi piksel yang kosong saat augmentasi
)

# List semua direktori label dalam direktori utama
label_dirs = [f.path for f in os.scandir(main_directory) if f.is_dir()]

# Loop melalui setiap direktori label
for directory in label_dirs:
    # Ambil semua path gambar dengan ekstensi .png dalam direktori label
    images = glob.glob(os.path.join(directory, '*.png'))
    
    # Loop melalui setiap gambar
    for image_path in images:
        print(image_path)
        # Baca gambar menggunakan OpenCV dan konversi warna ke RGB
        img = cv2.cvtColor(cv2.imread(image_path, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB)
        
        # Reshape gambar menjadi bentuk yang sesuai dengan generator
        image = img.reshape((1, ) + img.shape) 
        
        # Ekstrak nama file tanpa ekstensi dari path gambar
        base_name = os.path.basename(image_path)  # Misal: ah_01.png
        file_name_without_ext = os.path.splitext(base_name)[0]  # Misal: ah_01

        # Ekstrak folder name dari nama file (Misal: dari ah_01, folder name menjadi AH)
        folder_name = file_name_without_ext.split('_')[0].upper()
        
        j = 0
        # Tentukan prefix untuk nama file yang akan disimpan
        prefix = f'aug_{file_name_without_ext.split("_")[0]+file_name_without_ext.split("_")[1]}'
        total_augmentasi = 5  # Jumlah total augmentasi yang diinginkan
        # Lakukan augmentasi gambar
        for batch in datagen.flow(image, batch_size=16, 
                                  save_to_dir=os.path.join(main_directory, folder_name), 
                                  save_prefix=prefix, 
                                  save_format='png'):
            j += 1
            if j == total_augmentasi:
                break
# Out:
# ../dataset/preprocessed/Induk anak huruf di samping\AH\ah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\AH\ah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\AH\ah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\AH\ah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\AH\ah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\AH\ah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\AI\ai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\AI\ai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\AI\ai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\AI\ai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\AI\ai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\AI\ai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\B\b_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\B\b_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\B\b_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\B\b_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\B\b_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\B\b_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAH\bah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAH\bah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAH\bah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAH\bah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAH\bah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAH\bah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAI\bai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAI\bai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAI\bai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAI\bai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAI\bai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\BAI\bai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\C\c_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\C\c_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\C\c_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\C\c_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\C\c_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\C\c_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAH\cah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAH\cah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAH\cah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAH\cah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAH\cah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAH\cah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAI\cai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAI\cai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAI\cai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAI\cai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAI\cai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\CAI\cai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\D\d_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\D\d_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\D\d_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\D\d_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\D\d_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\D\d_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAH\dah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAH\dah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAH\dah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAH\dah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAH\dah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAH\dah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAI\dai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAI\dai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAI\dai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAI\dai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAI\dai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\DAI\dai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\G\g_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\G\g_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\G\g_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\G\g_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\G\g_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\G\g_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAH\gah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAH\gah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAH\gah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAH\gah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAH\gah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAH\gah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAI\gai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAI\gai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAI\gai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAI\gai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAI\gai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\GAI\gai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\GH\gh_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\GH\gh_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\GH\gh_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\GH\gh_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\GH\gh_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\GH\gh_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAH\ghah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAH\ghah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAH\ghah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAH\ghah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAH\ghah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAH\ghah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAI\ghai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAI\ghai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAI\ghai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAI\ghai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAI\ghai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\GHAI\ghai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\H\h_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\H\h_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\H\h_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\H\h_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\H\h_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\H\h_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAH\hah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAH\hah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAH\hah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAH\hah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAH\hah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAH\hah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAI\hai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAI\hai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAI\hai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAI\hai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAI\hai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\HAI\hai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\J\j_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\J\j_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\J\j_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\J\j_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\J\j_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\J\j_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAH\jah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAH\jah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAH\jah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAH\jah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAH\jah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAH\jah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAI\jai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAI\jai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAI\jai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAI\jai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAI\jai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\JAI\jai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\K\k_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\K\k_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\K\k_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\K\k_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\K\k_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\K\k_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAH\kah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAH\kah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAH\kah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAH\kah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAH\kah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAH\kah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAI\kai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAI\kai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAI\kai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAI\kai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAI\kai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\KAI\kai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\L\l_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\L\l_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\L\l_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\L\l_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\L\l_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\L\l_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAH\lah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAH\lah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAH\lah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAH\lah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAH\lah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAH\lah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAI\lai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAI\lai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAI\lai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAI\lai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAI\lai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\LAI\lai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\M\m_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\M\m_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\M\m_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\M\m_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\M\m_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\M\m_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAH\mah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAH\mah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAH\mah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAH\mah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAH\mah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAH\mah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAI\mai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAI\mai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAI\mai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAI\mai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAI\mai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\MAI\mai__03.png
# ../dataset/preprocessed/Induk anak huruf di samping\N\n_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\N\n_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\N\n_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\N\n_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\N\n_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\N\n_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAH\nah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAH\nah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAH\nah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAH\nah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAH\nah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAH\nah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAI\nai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAI\nai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAI\nai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAI\nai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAI\nai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\NAI\nai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\NG\ng_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\NG\ng_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\NG\ng_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\NG\ng_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\NG\ng_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\NG\ng_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAH\ngah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAH\ngah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAH\ngah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAH\ngah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAH\ngah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAH\ngah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAI\ngai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAI\ngai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAI\ngai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAI\ngai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAI\ngai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\NGAI\ngai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\NY\ny_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\NY\ny_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\NY\ny_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\NY\ny_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\NY\ny_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\NY\ny_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAH\nyah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAH\nyah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAH\nyah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAH\nyah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAH\nyah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAH\nyah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAI\nyai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAI\nyai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAI\nyai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAI\nyai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAI\nyai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\NYAI\nyai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\P\p_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\P\p_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\P\p_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\P\p_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\P\p_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\P\p_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAH\pah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAH\pah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAH\pah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAH\pah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAH\pah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAH\pah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAI\pai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAI\pai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAI\pai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAI\pai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAI\pai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\PAI\pai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\R\r_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\R\r_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\R\r_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\R\r_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\R\r_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\R\r_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAH\rah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAH\rah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAH\rah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAH\rah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAH\rah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAH\rah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAI\rai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAI\rai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAI\rai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAI\rai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAI\rai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\RAI\rai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\S\s_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\S\s_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\S\s_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\S\s_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\S\s_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\S\s_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAH\sah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAH\sah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAH\sah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAH\sah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAH\sah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAH\sah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAI\sai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAI\sai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAI\sai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAI\sai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAI\sai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\SAI\sai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\T\t_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\T\t_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\T\t_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\T\t_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\T\t_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\T\t_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAH\tah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAH\tah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAH\tah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAH\tah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAH\tah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAH\tah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAI\tai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAI\tai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAI\tai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAI\tai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAI\tai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\TAI\tai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\W\w_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\W\w_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\W\w_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\W\w_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\W\w_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\W\w_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAH\wah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAH\wah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAH\wah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAH\wah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAH\wah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAH\wah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAI\wai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAI\wai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAI\wai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAI\wai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAI\wai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\WAI\wai_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\Y\y_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\Y\y_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\Y\y_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\Y\y_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\Y\y_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\Y\y_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAH\yah_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAH\yah_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAH\yah_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAH\yah_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAH\yah_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAH\yah_06.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAI\yai_01.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAI\yai_02.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAI\yai_03.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAI\yai_04.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAI\yai_05.png
# ../dataset/preprocessed/Induk anak huruf di samping\YAI\yai_06.png

# %%
# List setiap label_dir dalam direktori utama
label_dirs = [f.path for f in os.scandir(main_directory) if f.is_dir()]
label_dirs

# Membaca semua file yang ada di setiap label_dir
all_images = []
aug_minus = []
for directory in label_dirs:
    count = 0
    for file in os.listdir(directory):
        count += 1

    if count != 36:
        print(directory.split("\\")[-1], count)
        aug_minus.append(directory.split("\\")[-1])
        for f in directory:
            all_images.append(f)

print(aug_minus, len(aug_minus))
# Out:
# [] 0

# %% [markdown]
# # Untuk jumlah Augmentasi yang kurang

# %%
def reset_aug(folder):
    # Tentukan direktori folder
    dir_del = f'{main_directory}/{folder}/'
    print(dir_del)

    # Mencari semua file dengan format nama aug*.png dalam folder
    files_to_delete = glob.glob(os.path.join(dir_del, "aug*.png"))
    print(folder, len(files_to_delete))

    # Hapus setiap file
    for f in files_to_delete:
        os.remove(f)

for i in aug_minus:
    reset_aug(i)


def augmentation(image, total):
    image = image.reshape((1, ) + image.shape) 
    datagen = ImageDataGenerator(
        rotation_range=30,    
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        # vertical_flip=True,
        fill_mode='nearest')

    j = 0
    for batch in datagen.flow(image, batch_size=16, 
                              save_to_dir= os.path.join(main_directory, folder_name), 
                              save_prefix=f'aug_{file_name_without_ext.split("_")[0]+file_name_without_ext.split("_")[1]}', 
                              save_format='png'):
        j += 1
        if j == total:
            break
# Out:
# ../dataset/preprocessed/Induk anak huruf di samping/BAI/
# BAI 29

# %%
# Membaca semua file yang ada di setiap label_dir
all_images = []
for i, directory in enumerate(label_dirs):
    if directory.split("\\")[-1] in aug_minus:
        print(directory.split("\\")[-1])
        all_images.extend(glob.glob(os.path.join(directory, '*.png')))     
len(all_images)

for i, image_path in enumerate(all_images):
    # Ekstrak nama file tanpa ekstensi dari path gambar
    base_name = os.path.basename(image_path)  # Misal: ah_01.png
    file_name_without_ext = os.path.splitext(base_name)[0]  # Misal: ah_01

    # Ekstrak folder name dari nama file (Misal: dari ah_01, folder name menjadi AH)
    folder_name = file_name_without_ext.split('_')[0].upper()

    print(i, file_name_without_ext.split('_')[0]+file_name_without_ext.split('_')[1], folder_name)
    img = cv2.imread(image_path, cv2.IMREAD_COLOR)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    augmentation(img, 5)
# Out:
# BAI
# 0 bai01 BAI
# 1 bai02 BAI
# 2 bai03 BAI
# 3 bai04 BAI
# 4 bai05 BAI
# 5 bai06 BAI
